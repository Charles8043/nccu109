# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
A=[0,0,2,4,6,8,8]
B=[0,50,35,20,35,50,0]
plot(A,B)

# %%
H=[19.1,19.6,22.1,25.7,29.2,32.0,34.3,33.8,31.1,27.5,24.2,20.7]
L=[13.9,14.2,15.8,19.0,22.3,24.6,26.3,26.1,24.8,22.3,19.3,15.6]
plot(H)
plot(L)

# %%
a=100*1000
b=150*1000
c=230*1000
d=80*1000

# %%
plot([a,a+b,a+b+c,a+b+c+d])

# %%
pie([a,a+b,a+b+c,a+b+c+d])
# Out:
# ([<matplotlib.patches.Wedge at 0x14c694fcf88>,
# ...
#  [Text(1.0720241462539195, 0.24650401588727708, ''),
#   Text(0.5784535203470075, 0.9356236020954979, ''),
#   Text(-0.978408542144353, 0.502709383897856, ''),
#   Text(0.33044707679391266, -1.0491924177377372, '')])

# %%
# 每月交通費
bus=int(input("公車:"))
mrt=int(input("捷運:"))
thsr=int(input("高鐵:"))
# Out:
# 公車:50
# 捷運:250
# 高鐵:1000

# %%
pie([bus,mrt,thsr])
# Out:
# ([<matplotlib.patches.Wedge at 0x14c695d8f88>,
# ...
#  [Text(1.0919797609110324, 0.132590353196169, ''),
#   Text(0.7294349077576502, 0.8233618374351513, ''),
#   Text(-0.8233617691405228, -0.7294349848463457, '')])
