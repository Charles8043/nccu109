# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import requests
import time
import json
from bs4 import BeautifulSoup


PTT_URL = 'https://www.ptt.cc'


def get_web_page(url):
    resp = requests.get(
        url=url,
        cookies={'over18': '1'}
    )
    if resp.status_code != 200:
        print('Invalid url:', resp.url)
        return None
    else:
        return resp.text


def get_articles(dom, date):
    soup = BeautifulSoup(dom, 'html5lib')


    paging_div = soup.find('div', 'btn-group btn-group-paging')
    prev_url = paging_div.find_all('a')[1]['href']

    articles = []  
    divs = soup.find_all('div', 'r-ent')
    for d in divs:
        if d.find('div', 'date').text.strip() == date:  
            
            push_count = 0
            push_str = d.find('div', 'nrec').text
            if push_str:
                try:
                    push_count = int(push_str) 
                except ValueError:

                    if push_str == '爆':
                        push_count = 99
                    elif push_str.startswith('X'):
                        push_count = -10

            if d.find('a'): 
                href = d.find('a')['href']
                title = d.find('a').text
                author = d.find('div', 'author').text if d.find('div', 'author') else ''
                articles.append({
                    'title': title,
                    'href': href,
                    'push_count': push_count,
                    'author': author
                })
    return articles, prev_url


def get_author_ids(posts, pattern):
    ids = set()
    for post in posts:
        if pattern in post['author']:
            ids.add(post['author'])
    return ids

# %%
if __name__ == '__main__':
    current_page = get_web_page(PTT_URL + '/bbs/Gossiping/index.html')
    if current_page:
        articles = []
        today = time.strftime("%m/%d").lstrip('0')
        current_articles, prev_url = get_articles(current_page, today)
        while current_articles:
            articles += current_articles
            current_page = get_web_page(PTT_URL + prev_url)
            current_articles, prev_url = get_articles(current_page, today)

        print('今天有', len(articles), '篇文章')
        threshold = 50
        print('熱門文章(> %d 推):' % (threshold))
        for a in articles:
            if int(a['push_count']) > threshold:
                print(a)
        with open('gossiping.json', 'w', encoding='utf-8') as f:
            json.dump(articles, f, indent=2, sort_keys=True, ensure_ascii=False)
# Out:
# 今天有 2130 篇文章
# 熱門文章(> 50 推):
# {'title': '[問卦] 人在德國 還有幾集可以逃？', 'href': '/bbs/Gossiping/M.1583848301.A.7F9.html', 'push_count': 54, 'author': 'jim18324'}
# {'title': '[爆卦] 第二波武漢台商華航包機已起飛', 'href': '/bbs/Gossiping/M.1583848187.A.98A.html', 'push_count': 52, 'author': 'huangjyuan'}
# {'title': '[問卦] 最想宮崎駿裡的誰當你女友？', 'href': '/bbs/Gossiping/M.1583847523.A.70D.html', 'push_count': 73, 'author': 'ericgary'}
# {'title': '[新聞] 媽媽體溫37.1度未過關！武漢華航包機重開', 'href': '/bbs/Gossiping/M.1583846938.A.3FC.html', 'push_count': 98, 'author': 'kimiboy'}
# {'title': '[問卦] 大家看過最詭異的書是什麼？', 'href': '/bbs/Gossiping/M.1583845920.A.EA1.html', 'push_count': 72, 'author': 'pennyleo'}
# {'title': '[新聞] 第二批武漢包機延誤！旅客體溫過高 又滑', 'href': '/bbs/Gossiping/M.1583844688.A.FFC.html', 'push_count': 99, 'author': 'cheinshin'}
# {'title': '[新聞] 華航專機旅客體溫過高 飛機後推後又滑回', 'href': '/bbs/Gossiping/M.1583844423.A.76C.html', 'push_count': 75, 'author': 'KKmex'}
# {'title': '[問卦] 宮崎駿哪部必看啊？', 'href': '/bbs/Gossiping/M.1583843618.A.D96.html', 'push_count': 66, 'author': 'Mews'}
# {'title': '[新聞]“#我沒事，你先來”韓網掀起口罩禮讓關懷', 'href': '/bbs/Gossiping/M.1583842624.A.F9B.html', 'push_count': 99, 'author': 'MafuyuShiina'}
# {'title': '[新聞] 「權貴三審定讞卻逍遙法外...」時力提3法', 'href': '/bbs/Gossiping/M.1583841803.A.C6A.html', 'push_count': 86, 'author': 'ueewen'}
# {'title': '[新聞] 快訊／18人未配合檢疫、11人消失！第二', 'href': '/bbs/Gossiping/M.1583842043.A.03C.html', 'push_count': 99, 'author': 'Sky77777777'}
# {'title': '[爆卦] 台灣製的南韓口罩地圖上線', 'href': '/bbs/Gossiping/M.1583841410.A.3D2.html', 'push_count': 99, 'author': 'olctw'}
# {'title': '[新聞] 連續8個月凌晨大喊「我愛你」 強制罪起訴', 'href': '/bbs/Gossiping/M.1583840293.A.D48.html', 'push_count': 66, 'author': 'ytkuang'}
# {'title': '[新聞] 除了陳時中有備位指揮官？蘇貞昌：我有想', 'href': '/bbs/Gossiping/M.1583838667.A.6D0.html', 'push_count': 99, 'author': 'huchihkuei01'}
# {'title': '[新聞] 4月口罩站上可「防疫外交」門檻 給哪國', 'href': '/bbs/Gossiping/M.1583837295.A.0BE.html', 'push_count': 99, 'author': 'runa2'}
# {'title': '[問卦] 日本樂壇在亞洲退燒原因？', 'href': '/bbs/Gossiping/M.1583837660.A.8C2.html', 'push_count': 87, 'author': 'askaleroux'}
# {'title': '[爆卦] 網傳WHO中國代表發言片段宣稱「台灣研發', 'href': '/bbs/Gossiping/M.1583837076.A.C3F.html', 'push_count': 99, 'author': 'batt0909'}
# {'title': 'Re: [問卦] KKC為什麼把文章都刪除了?', 'href': '/bbs/Gossiping/M.1583837165.A.F07.html', 'push_count': 75, 'author': 'ThorFukt'}
# {'title': '[問卦] 聽伍佰哪幾首歌最內行？', 'href': '/bbs/Gossiping/M.1583836013.A.680.html', 'push_count': 99, 'author': 'bn5566'}
# {'title': '[爆卦] 日本也要搞口罩國家隊啦！', 'href': '/bbs/Gossiping/M.1583835395.A.DF3.html', 'push_count': 99, 'author': 'arashiverve'}
# {'title': '[問卦] 人在嘉義市，晚餐該吃什麼??', 'href': '/bbs/Gossiping/M.1583835427.A.F5A.html', 'push_count': 62, 'author': 'k44754'}
# {'title': 'Re: [問卦] KKC為什麼把文章都刪除了?', 'href': '/bbs/Gossiping/M.1583833853.A.A38.html', 'push_count': 99, 'author': 'zhtw'}
# {'title': '[新聞] 回擊耿爽 外交部：病毒從哪來的 沒有貶', 'href': '/bbs/Gossiping/M.1583834156.A.946.html', 'push_count': 99, 'author': 'ishowhand'}
# {'title': 'Re: [新聞] 大三決定不當老師 刪臉書、IG...她應屆', 'href': '/bbs/Gossiping/M.1583834185.A.4AF.html', 'push_count': 99, 'author': 'i2taiwan'}
# {'title': '[爆卦] 德、法、瑞等國病例正沿著義大利趨勢上升', 'href': '/bbs/Gossiping/M.1583833245.A.135.html', 'push_count': 99, 'author': 'derekhsu'}
# {'title': '[新聞] 香港專家：70％人口有抗體疫情才紓緩「圍', 'href': '/bbs/Gossiping/M.1583832604.A.48C.html', 'push_count': 94, 'author': 'skn60694'}
# {'title': 'Re: [新聞] 大三決定不當老師 刪臉書、IG...她應屆', 'href': '/bbs/Gossiping/M.1583831395.A.BB2.html', 'push_count': 99, 'author': 'Day731'}
# {'title': '[新聞] 韓國瑜完了！副市長怒槓罷韓團體 丁學偉', 'href': '/bbs/Gossiping/M.1583831126.A.8C4.html', 'push_count': 67, 'author': 'heavenkghs'}
# {'title': '[新聞] 楊瓊瓔促給台中人「一週7片口罩」 蘇揆：', 'href': '/bbs/Gossiping/M.1583831245.A.3DF.html', 'push_count': 99, 'author': 'greg11321'}
# {'title': 'Re: [新聞] 大三決定不當老師 刪臉書、IG...她應屆', 'href': '/bbs/Gossiping/M.1583829935.A.F09.html', 'push_count': 93, 'author': 'tosay'}
# {'title': '[問卦] 有沒有經典歌很多是伍佰作詞作曲的掛?', 'href': '/bbs/Gossiping/M.1583830161.A.AE1.html', 'push_count': 52, 'author': 'googled'}
# {'title': '[新聞] 又一公主號需檢疫 加勒比公主號暫禁入港', 'href': '/bbs/Gossiping/M.1583829225.A.520.html', 'push_count': 66, 'author': 'yukihira'}
# {'title': 'Re: [新聞] 大三決定不當老師 刪臉書、IG...她應屆', 'href': '/bbs/Gossiping/M.1583828004.A.1BE.html', 'push_count': 99, 'author': 'panzer1224'}
# {'title': '[新聞] 真的GG了…男遇盤查持刀襲擊 警開槍打中要害', 'href': '/bbs/Gossiping/M.1583827407.A.220.html', 'push_count': 99, 'author': 'inglee'}
# {'title': '[爆卦] 蕭邦鋼琴大賽台灣人國籍變PRC TAIWAN', 'href': '/bbs/Gossiping/M.1583827414.A.EC1.html', 'push_count': 65, 'author': 'silbermond4u'}
# {'title': 'Re: [問卦] 館長衣服真的CP值很高嗎?', 'href': '/bbs/Gossiping/M.1583826642.A.894.html', 'push_count': 57, 'author': 'tvboy'}
# {'title': '[新聞] 「老婆被強姦我在裡面關」 殺人被判13年', 'href': '/bbs/Gossiping/M.1583825335.A.E50.html', 'push_count': 80, 'author': 'kingtama'}
# {'title': '[新聞] 武漢14家方艙醫院全部休艙', 'href': '/bbs/Gossiping/M.1583825253.A.954.html', 'push_count': 54, 'author': 'william8403'}
# {'title': '[新聞] 武漢肺炎》不甩中國 日副首相麻生︰「武', 'href': '/bbs/Gossiping/M.1583824334.A.10D.html', 'push_count': 99, 'author': 'Toyosushij'}
# {'title': 'Re: [新聞] 管碧玲護航 國土計畫法周五立法院會再闖', 'href': '/bbs/Gossiping/M.1583822563.A.7F3.html', 'push_count': 99, 'author': 'deann'}
# {'title': '[新聞]鎖國防疫？以色列宣布:所有入境者都先隔離', 'href': '/bbs/Gossiping/M.1583822773.A.02F.html', 'push_count': 99, 'author': 'sportlotte'}
# {'title': '[新聞] 拿護照出國常被誤當中國人 陳柏惟、林昶', 'href': '/bbs/Gossiping/M.1583821834.A.25F.html', 'push_count': 99, 'author': 'Luwan'}
# {'title': '[新聞] 口罩實名制2.0周四上路 線上預購每筆自付', 'href': '/bbs/Gossiping/M.1583820123.A.075.html', 'push_count': 99, 'author': 'blueadam193'}
# {'title': '[問卦] 跟女同事開車出差到底要坐哪裡', 'href': '/bbs/Gossiping/M.1583820207.A.301.html', 'push_count': 95, 'author': 'GentleJena'}
# {'title': '[新聞] 無薪假改減班休息 民眾黨：蔡可拿諾貝爾', 'href': '/bbs/Gossiping/M.1583819587.A.518.html', 'push_count': 99, 'author': 'vntlu'}
# {'title': '[新聞] 時力要求追回非法解雇勞工企業紓困補助 ', 'href': '/bbs/Gossiping/M.1583819588.A.D52.html', 'push_count': 61, 'author': 'y1896547'}
# {'title': '[問卦] 楊蕙如還能以什麼罪起訴她？', 'href': '/bbs/Gossiping/M.1583819627.A.C08.html', 'push_count': 99, 'author': 'parttime'}
# {'title': '[問卦] 如果要捐物資給義大利的話要捐什麼?', 'href': '/bbs/Gossiping/M.1583819202.A.AE5.html', 'push_count': 89, 'author': 'pdz'}
# {'title': '[爆卦] 網路預購物流費用7元!!', 'href': '/bbs/Gossiping/M.1583819312.A.48A.html', 'push_count': 99, 'author': 'reason825'}
# {'title': '[爆卦] 口罩實名制2.0、新增兩例確診', 'href': '/bbs/Gossiping/M.1583818963.A.92D.html', 'push_count': 51, 'author': 'laptic'}
# {'title': '[新聞] 全球孤立成就台灣！法媒：台灣憑一己之', 'href': '/bbs/Gossiping/M.1583817134.A.46B.html', 'push_count': 99, 'author': 'teramars'}
# {'title': '[爆卦] 黃暐瀚:為什麼台灣還稱武漢肺炎?', 'href': '/bbs/Gossiping/M.1583817142.A.6B8.html', 'push_count': 99, 'author': 'cleversun'}
# {'title': '[問卦] 灣灣是褒還是貶，被叫灣灣有感覺嗎', 'href': '/bbs/Gossiping/M.1583816403.A.CAF.html', 'push_count': 88, 'author': 'DemonPomelo'}
# {'title': '[問卦] 全家是何時何事開始，能與7-11分庭抗禮？', 'href': '/bbs/Gossiping/M.1583815726.A.B68.html', 'push_count': 99, 'author': 'hk5566'}
# {'title': '[新聞] 文化部建議梅花座 蔡壁如:中央空調都一樣', 'href': '/bbs/Gossiping/M.1583814931.A.300.html', 'push_count': 60, 'author': 'xamous'}
# {'title': '[問卦] 下周油價大跌 3.8元', 'href': '/bbs/Gossiping/M.1583814689.A.12E.html', 'push_count': 99, 'author': 'h0304'}
# {'title': '[新聞] 美國會議員致函WHO 要求直接邀請台灣參', 'href': '/bbs/Gossiping/M.1583814481.A.74A.html', 'push_count': 99, 'author': 'Oisiossos'}
# {'title': '[爆卦] 蒙古國宣布首都封鎖', 'href': '/bbs/Gossiping/M.1583813696.A.AF5.html', 'push_count': 99, 'author': 'derekhsu'}
# {'title': '[新聞] 捷克總理有種！要中國撤換發威脅信大使 ', 'href': '/bbs/Gossiping/M.1583813084.A.E19.html', 'push_count': 99, 'author': 'sgzt'}
# {'title': '[問卦] 台灣到底做對了什麼？', 'href': '/bbs/Gossiping/M.1583813233.A.21C.html', 'push_count': 99, 'author': 'PoorHunter'}
# {'title': '[新聞] 不甩WHO！美國務卿狂稱「武漢病毒」 耿', 'href': '/bbs/Gossiping/M.1583812175.A.480.html', 'push_count': 99, 'author': 'kymco9999'}
# {'title': '[問卦] 義大利 VS 湖北省 現在要去你會去哪？', 'href': '/bbs/Gossiping/M.1583812382.A.FC6.html', 'push_count': 63, 'author': 'smd1201'}
# {'title': '[問卦] 有人預料到台灣能守這麼久沒社區嗎？', 'href': '/bbs/Gossiping/M.1583810949.A.9C8.html', 'push_count': 56, 'author': 'norvasc'}
# {'title': '[新聞] 快訊／封城後48天！習近平抵達武漢考察新', 'href': '/bbs/Gossiping/M.1583811208.A.47C.html', 'push_count': 86, 'author': 'nba887215'}
# {'title': '[新聞] 柯文哲：此次疫情是推政府e化時機', 'href': '/bbs/Gossiping/M.1583810374.A.BF1.html', 'push_count': 99, 'author': 'Rogerisme'}
# {'title': '[問卦] 露天拍賣是不是沒落了?', 'href': '/bbs/Gossiping/M.1583810435.A.F2E.html', 'push_count': 83, 'author': 'loxic'}
# {'title': '[問卦] 千千是不是算油土伯裡聰明的?', 'href': '/bbs/Gossiping/M.1583810623.A.7D6.html', 'push_count': 56, 'author': 'wcpsgb'}
# {'title': '[新聞] 男大生「化骨水」潑死8旬翁：我只是想嚇', 'href': '/bbs/Gossiping/M.1583810743.A.F9D.html', 'push_count': 99, 'author': 's27052705'}
# {'title': '[參選] mother ~(@[email\xa0protected])~火星章魚怪~(@[email\xa0protected])~', 'href': '/bbs/Gossiping/M.1583809537.A.591.html', 'push_count': 99, 'author': 'mother'}
# {'title': 'Re: [問卦] 紙箱睡公園怎麼防大雨?', 'href': '/bbs/Gossiping/M.1583808501.A.088.html', 'push_count': 99, 'author': 'forsakesheep'}
# {'title': '[新聞] 美商會長籲川普買下台灣 蘇揆：我們不賣', 'href': '/bbs/Gossiping/M.1583808099.A.5C7.html', 'push_count': 99, 'author': 'helikon'}
# {'title': '[問卦] 直接跟我說能不能進場就好', 'href': '/bbs/Gossiping/M.1583808237.A.2EA.html', 'push_count': 52, 'author': 'pttbeer'}
# {'title': '[新聞] 用命換「40萬↑」月薪！台北港2引水人落', 'href': '/bbs/Gossiping/M.1583807636.A.70B.html', 'push_count': 99, 'author': 'kivan00'}
# {'title': '[爆卦] 病毒大省湖北開始大規模開工招工了', 'href': '/bbs/Gossiping/M.1583804608.A.E9F.html', 'push_count': 61, 'author': 'gongling'}
# {'title': '[問卦] 大家講過最傷人的一句話是什麼呢?', 'href': '/bbs/Gossiping/M.1583805283.A.4E2.html', 'push_count': 78, 'author': 'jeff0025'}
# {'title': '[問卦] 有沒有無傷大雅但可以報復社會的方式', 'href': '/bbs/Gossiping/M.1583803703.A.0F5.html', 'push_count': 76, 'author': 'LastDinosaur'}
# {'title': '[新聞] 男女人數比例60:0 員林市公所扮紅娘傻眼', 'href': '/bbs/Gossiping/M.1583803799.A.DFB.html', 'push_count': 99, 'author': 'Cathay'}
# {'title': '[爆卦] 全台灣的先知都在這邊啦!!!!', 'href': '/bbs/Gossiping/M.1583802549.A.1C5.html', 'push_count': 71, 'author': 'bigbowl'}
# {'title': '[新聞] 蔡總統：台灣製口罩 本週可達單日千萬片', 'href': '/bbs/Gossiping/M.1583802118.A.092.html', 'push_count': 99, 'author': 'Tiffwyetha'}
# {'title': '[新聞] 「18萬我繳得起」奧迪男拒酒測長腿女友連坐', 'href': '/bbs/Gossiping/M.1583801099.A.A27.html', 'push_count': 73, 'author': 'kenny1300175'}
# {'title': '[爆卦] 今日淪陷：阿爾巴尼亞、賽普勒斯、汶萊、', 'href': '/bbs/Gossiping/M.1583799134.A.801.html', 'push_count': 66, 'author': 'eeveelugia2'}
# {'title': '[新聞] 快訊／義大利全國封城！\u3000總理緊急下令：', 'href': '/bbs/Gossiping/M.1583799417.A.F10.html', 'push_count': 99, 'author': 'nightwing'}
# {'title': '[問卦] == 和 = = 你是哪一派', 'href': '/bbs/Gossiping/M.1583799623.A.7AF.html', 'push_count': 99, 'author': 'O300'}
# {'title': '[新聞] 台北男夜衝新竹幫大一女友慶生：給妳驚', 'href': '/bbs/Gossiping/M.1583799760.A.744.html', 'push_count': 64, 'author': 'DDDDRR'}
# {'title': '[新聞] 台北男夜衝新竹幫大一女友慶生：給妳驚', 'href': '/bbs/Gossiping/M.1583798427.A.0DE.html', 'push_count': 89, 'author': 'Eliphalet'}
# {'title': '[問卦] 股市會跌 房價卻不會？還是快了？', 'href': '/bbs/Gossiping/M.1583798603.A.403.html', 'push_count': 52, 'author': 'mytaiwan'}
# {'title': '[問卦] 好多SNG車在校外啊', 'href': '/bbs/Gossiping/M.1583797442.A.09D.html', 'push_count': 90, 'author': 'oppor1l'}
# {'title': '[新聞] 男友夜衝送生日驚喜 女大生嘿咻前男友掰', 'href': '/bbs/Gossiping/M.1583792428.A.84A.html', 'push_count': 88, 'author': 'Workforme'}
# {'title': '[爆卦] 義大利全境封鎖', 'href': '/bbs/Gossiping/M.1583787123.A.375.html', 'push_count': 99, 'author': 'coolbaby'}
# {'title': '[爆卦] 義大利全境封鎖', 'href': '/bbs/Gossiping/M.1583787626.A.601.html', 'push_count': 63, 'author': 'rnmbgcd'}
# {'title': '[問卦] 現在大家是不是都在等9點見證歷史?', 'href': '/bbs/Gossiping/M.1583791215.A.D56.html', 'push_count': 73, 'author': 'fox1234'}
# {'title': '[爆卦] 法國文化部長檢測爲陽性', 'href': '/bbs/Gossiping/M.1583782390.A.AC2.html', 'push_count': 99, 'author': 'alexcai'}
# {'title': '[問卦] 有沒有憂鬱症休學的八卦', 'href': '/bbs/Gossiping/M.1583784157.A.9CA.html', 'push_count': 62, 'author': 'Salvadoran'}
# {'title': '[問卦] 各地天氣回報！', 'href': '/bbs/Gossiping/M.1583777806.A.477.html', 'push_count': 91, 'author': 'Bainite'}
# {'title': '[新聞] 蘇貞昌令政治人物退官股公司 桃勤、華儲董座遭拔', 'href': '/bbs/Gossiping/M.1583776497.A.F32.html', 'push_count': 99, 'author': 'chart'}
# {'title': '[爆卦] 義大利9172感染死463', 'href': '/bbs/Gossiping/M.1583775954.A.C4C.html', 'push_count': 99, 'author': 'papaganono'}
# {'title': '[新聞] 武漢肺炎／湖北台胞第二批包機 華航東航', 'href': '/bbs/Gossiping/M.1583771027.A.450.html', 'push_count': 74, 'author': 'cherrywish'}
# {'title': '[問卦] 大家實名制後買過幾次口罩', 'href': '/bbs/Gossiping/M.1583770458.A.F38.html', 'push_count': 99, 'author': 'cjh880320'}
# {'title': '[爆卦] 義大利50名囚犯趁亂逃獄劫車', 'href': '/bbs/Gossiping/M.1583770710.A.44F.html', 'push_count': 99, 'author': 'derekhsu'}
# {'title': 'Re: [爆卦] 柯文哲:向國民黨說聲加油', 'href': '/bbs/Gossiping/M.1583769991.A.4FC.html', 'push_count': 98, 'author': 'NARUTO'}
# {'title': '[爆卦] 口罩過剩藥局將停配送3天 兒童將回收', 'href': '/bbs/Gossiping/M.1583770135.A.21E.html', 'push_count': 84, 'author': 'akway'}
